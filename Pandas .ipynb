# %% [markdown]
# ## Pandas
# is an open source library providing high-performance, easy to use data structure and data analysis tools for the Python programming language.
# - Enhance analytical work if your data set contains missing values,
# - Or when we have to combine information across several data sets.
# - has the ability to import data and export data to, an extensive set of file formats.
# - Best for analysing datasets containing multiple types of information.(Numbers, Boolean data, Strings, Date or Time values)

# %% [markdown]
# ### Pandas Series

# %%
import pandas as pd

# %%
Price_a = [2, 3, 4, 5]
Price_a
# Out:
# [2, 3, 4, 5]

# %%
type(Price_a)
# Out:
# list

# %%
series = pd.Series(Price_a)
print(series)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Object
# Python object contain:
# - Data
# - Metadata (Info about the data)
# - Related functionalities

# %% [markdown]
# ### Attribute
# A variable providing metadata about an object

# %% [markdown]
# ### Method
# A function that can be associated with an object

# %%
series_a = pd.Series([10, 20, 30, 40, 50])
series_a
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# d.type = data type
series_a.dtype
# Out:
# dtype('int64')

# %%
#size
series_a.size
# Out:
# 5

# %%
product_categories = pd.Series(['A', 'B', 'C', 'D'])
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# dtype: object

# %%
product_categories.dtype
# Out:
# dtype('O')

# %%
product_categories.size
# Out:
# 4

# %%
type(product_categories.size)
# Out:
# int

# %%
print(product_categories.name)
# Out:
# None

# %% [markdown]
# - product_categories- the name we can use to refer to that object in our code.
# - The object name, the one you want to see whenever displaying its contents

# %%
product_categories.name = "PC"
product_categories.name
# Out:
# 'PC'

# %%
product_categories
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# Name: PC, dtype: object

# %% [markdown]
# The attributes related to a certain Python object allow us to extract information about it but they are not meant to alter or modify its content in any way.

# %% [markdown]
# ### Question
# Create a Pandas Series object, called work_experience_years, which should contain the following integers in the given order: 5, 8, 3, and 10.

# %%
work_experience_years = pd.Series([5, 8, 3, 10])
print(work_experience_years)
# Out:
# 0     5
# 1     8
# 2     3
# 3    10
# dtype: int64

# %% [markdown]
# ### Q
# Convert the work_experience_years object from a Pandas Series into a NumPy array. Accomplish this task without overwriting the contents of work_experience_years.

# %%
work_experience_years = np.array([5,8,3,10])
print(work_experience_years)
# Out:
# [ 5  8  3 10]

# %% [markdown]
# ### Using an Index in Pandas

# %%
prices_per_category = {'Product A': 2250, 'Product B': 16600}
prices_per_category
# Out:
# {'Product A': 2250, 'Product B': 16600}

# %%
type(prices_per_category)
# Out:
# dict

# %%
prices_per_category = pd.Series(prices_per_category)

# %%
prices_per_category
# Out:
# Product A     2250
# Product B    16600
# dtype: int64

# %% [markdown]
# ## Imp points
# - An inde allows you to refer to a position within a sequence, or - in other words- a set of values in a sequenced order.
# - You will be able to quickly access the prices of the relevant categories through their respective indices.
# - The index data structure will often turn out to be a way to speed up your computations while working with large data sets.

# %% [markdown]
# ### Question
# Retrieve the index of workers_age

# %%
workers_age = {'Amy White':50, 'Jack Stewart':53, 'Richard Lauderdale':35, 'Sara Johnson':43}
workers_age = pd.Series(workers_age)

# %%
workers_age
# Out:
# Amy White             50
# Jack Stewart          53
# Richard Lauderdale    35
# Sara Johnson          43
# dtype: int64

# %%
print(workers_age.index)
# Out:
# Index(['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], dtype='object')

# %% [markdown]
# ## Label based vs Position (zero) based Indexing

# %% [markdown]
# ### Data Structure
# - Explicit - way of def dt
# - Implicit - by default based on their values

# %% [markdown]
# ### Question
# Create a pandas Series object from a dictionary with keys "Martin" and "George" and values 8 and 5, respectively. Call this Series employees_work_exp, as from "workers work experience".

# %%
work_exp_dict = {"Martin": 8, "George": 5}
employees_work_exp = pd.Series(work_exp_dict)
print(employees_work_exp)
# Out:
# Martin    8
# George    5
# dtype: int64

# %% [markdown]
# Extract the first index value to verify that it is of the string data type.

# %%
employees_work_exp = pd.Series({'Martin':8, 'George':5})
employees_work_exp
# Out:
# Martin    8
# George    5
# dtype: int64

# %%
print(employees_work_exp.index[0])
# Out:
# Martin

# %% [markdown]
# Retrieve the index values of series_age to see they are numbers, which would indicate that they represent positioned data.

# %%
series_age = pd.Series(np.array([44, 54, 65, 35]))
print(series_age.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ### Question
# Use an appropriate method to extract the top five values from the employees_work_exp Series.
#
# Please be aware that pandas may automatically display the values of the object as floats as opposed to integers.

# %%
employees_work_exp = pd.Series({
'Amy White'   : 3,
'Jack Stewart'   : 5,
'Richard Lauderdale'  : 4.5,
'Sara Johnson'  : 22,
'Patrick Adams' : 28,
'Jessica Baker'  : 14,
'Peter Hunt'   : 4,
'Daniel Lloyd'  : 6,
'John Owen'   : 1.5,
'Jennifer Phillips'  : 10,
'Courtney Rogers'   : 4.5,
'Anne Robinson'  : 2,
})
print(employees_work_exp.head())
# Out:
# Amy White              3.0
# Jack Stewart           5.0
# Richard Lauderdale     4.5
# Sara Johnson          22.0
# Patrick Adams         28.0
# dtype: float64

# %%
employees_work_exp
# Out:
# Amy White              3.0
# Jack Stewart           5.0
# Richard Lauderdale     4.5
# Sara Johnson          22.0
# Patrick Adams         28.0
# Jessica Baker         14.0
# Peter Hunt             4.0
# Daniel Lloyd           6.0
# John Owen              1.5
# Jennifer Phillips     10.0
# Courtney Rogers        4.5
# Anne Robinson          2.0
# dtype: float64

# %%
employees_work_exp.min()
# Out:
# 1.5

# %%
employees_work_exp.max()
# Out:
# 28.0

# %%
employees_work_exp.idxmax()
# Out:
# 'Patrick Adams'

# %%
employees_work_exp.idxmin()
# Out:
# 'John Owen'

# %%
employees_work_exp.sum()
# Out:
# 104.5

# %%
employees_work_exp.tail()
# Out:
# Daniel Lloyd          6.0
# John Owen             1.5
# Jennifer Phillips    10.0
# Courtney Rogers       4.5
# Anne Robinson         2.0
# dtype: float64

# %% [markdown]
# ## Introduction to Pandas DataFrame

# %% [markdown]
# - What
# - Where it can be used

# %% [markdown]
# ### Creating Dataframes

# %% [markdown]
# 1. Construct DataFrames from a dictionary of lists

# %%
import pandas as pd
data = {'ProductName':['Product A', 'Product B', 'Product C'], 'ProductPrice':[22250, 16600, 12500]}
df = pd.DataFrame(data)
df
# Out:
#   ProductName  ProductPrice
# 0   Product A         22250
# 1   Product B         16600
# 2   Product C         12500

# %%
data = {'Name':['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], 'Age':['50', '53', '35', '43'], 'Working Experience(Yrs.)':['5','8','3','10']}
df = pd.DataFrame(data)

# %%
df
# Out:
#                  Name Age Working Experience(Yrs.)
# 0           Amy White  50                        5
# 1        Jack Stewart  53                        8
# 2  Richard Lauderdale  35                        3
# 3        Sara Johnson  43                       10

# %%
data = {'ProductName':['Product A', 'Product B', 'Product C'], 'ProductPrice':[22250, 16600, 12500]}
df = pd.DataFrame(data, index = ['A', 'B', 'C'])
df
# Out:
#   ProductName  ProductPrice
# A   Product A         22250
# B   Product B         16600
# C   Product C         12500

# %%
#Construct  a DataFrame from a list of dictionaries
import pandas as pd
data = [{'ProductName': "Product A", 'ProductPrice': 22340},{'ProductName': 'Product B', 'ProductPrice': 12332}]
df= pd.DataFrame(data)
df
# Out:
#   ProductName  ProductPrice
# 0   Product A         22340
# 1   Product B         12332

# %% [markdown]
# ## Creating in Professional way

# %%
df = pd.DataFrame(data = [['Product A', 22250], ['Product B', 233444], ['Product C', 12500]],
                 columns = ['ProductName', 'ProductPrice'],
                 index = ['A', 'B', 'C'])
df
# Out:
#   ProductName  ProductPrice
# A   Product A         22250
# B   Product B        233444
# C   Product C         12500

# %%
df.describe()
# Out:
#         ProductPrice
# count       3.000000
# mean    89398.000000
# std    124842.713892
# min     12500.000000
# 25%     17375.000000
# 50%     22250.000000
# 75%    127847.000000
# max    233444.000000

# %%
df.shape
# Out:
# (3, 2)

# %%
len(df)
# Out:
# 3

# %%
df.nunique()
# Out:
# ProductName     3
# ProductPrice    3
# dtype: int64

# %% [markdown]
# ## Data Selection
# - Data selection, or subset selection in a pandas DataFrame, means extracting elements, rows, columns, or subsets from such an object
#
# - Data selection allows us to work on just a portion of a dataset

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Lending-company.csv", index_col = 'StringID')
data
# Out:
#              LoanID    Product CustomerGender     Location    Region  \
# StringID
# LoanID_1          1  Product B         Female   Location 3  Region 2
# LoanID_2          2  Product D         Female   Location 6  Region 6
# LoanID_3          3  Product B           Male   Location 8  Region 3
# LoanID_4          4  Product A           Male  Location 26  Region 2
# LoanID_5          5  Product B         Female  Location 34  Region 3
# ...             ...        ...            ...          ...       ...
# LoanID_1039    1039  Product B           Male  Location 73  Region 6
# LoanID_1040    1040  Product A           Male  Location 82  Region 1
# LoanID_1041    1041  Product A   NotSpecified  Location 11  Region 4
# LoanID_1042    1042  Product B         Female  Location 26  Region 6
# LoanID_1043    1043  Product A   NotSpecified  Location 94  Region 6
#
#              TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  \
# StringID
# ...

# %%
data.head()
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female   Location 3  Region 2     17600.0
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_3       3  Product B           Male   Location 8  Region 3     16600.0
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
# LoanID_5       5  Product B         Female  Location 34  Region 3     21250.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_3  08/12/2016     1000         45          365       2260       3205
# LoanID_4         NaN     2200         45          365       3141       4166
# LoanID_5  28/10/2017     2200         55          365       3570       4745
#
# ...

# %%
data.Product
# Out:
# StringID
# LoanID_1       Product B
# LoanID_2       Product D
# LoanID_3       Product B
# LoanID_4       Product A
# LoanID_5       Product B
#                  ...
# LoanID_1039    Product B
# LoanID_1040    Product A
# LoanID_1041    Product A
# LoanID_1042    Product B
# LoanID_1043    Product A
# Name: Product, Length: 1043, dtype: object

# %%
data['Product']
# Out:
# StringID
# LoanID_1       Product B
# LoanID_2       Product D
# LoanID_3       Product B
# LoanID_4       Product A
# LoanID_5       Product B
#                  ...
# LoanID_1039    Product B
# LoanID_1040    Product A
# LoanID_1041    Product A
# LoanID_1042    Product B
# LoanID_1043    Product A
# Name: Product, Length: 1043, dtype: object

# %%
type(data['Product'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Observation
# - as shown above if we use single [] then we get series
# - to obtain dataframe type will use double bracets [[]]

# %%
m = data[['Product']]
m
# Out:
#                Product
# StringID
# LoanID_1     Product B
# LoanID_2     Product D
# LoanID_3     Product B
# LoanID_4     Product A
# LoanID_5     Product B
# ...                ...
# LoanID_1039  Product B
# LoanID_1040  Product A
# LoanID_1041  Product A
# LoanID_1042  Product B
# LoanID_1043  Product A
#
# [1043 rows x 1 columns]

# %%
type(m)
# Out:
# pandas.core.frame.DataFrame

# %%
data[['Location', 'Product']].head()
# Out:
#              Location    Product
# StringID
# LoanID_1   Location 3  Product B
# LoanID_2   Location 6  Product D
# LoanID_3   Location 8  Product B
# LoanID_4  Location 26  Product A
# LoanID_5  Location 34  Product B

# %% [markdown]
# ### iloc (Integer + Location)
# #### .iloc[row, column] has been programmed to deliver the desired portion of the dataset whether we provide one or two location specifiers.

# %%
# : used to extract all columns or rows
data.iloc[0:2]
# Out:
#           LoanID    Product CustomerGender    Location    Region  TotalPrice  \
# StringID
# LoanID_1       1  Product B         Female  Location 3  Region 2     17600.0
# LoanID_2       2  Product D         Female  Location 6  Region 6         NaN
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_1  04/07/2018     2200         45          365       3221       4166
# LoanID_2  02/01/2019     2200         45          365       3161       4096
#
#           AmtPaid360 LoanStatus
# StringID
# LoanID_1       14621     Active
# LoanID_2       16041     Active

# %%
data.iloc[:, 3]
# Out:
# StringID
# LoanID_1        Location 3
# LoanID_2        Location 6
# LoanID_3        Location 8
# LoanID_4       Location 26
# LoanID_5       Location 34
#                   ...
# LoanID_1039    Location 73
# LoanID_1040    Location 82
# LoanID_1041    Location 11
# LoanID_1042    Location 26
# LoanID_1043    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
data.iloc[[1, 3], :]
# Out:
#           LoanID    Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_2       2  Product D         Female   Location 6  Region 6         NaN
# LoanID_4       4  Product A           Male  Location 26  Region 2     17600.0
#
#            StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# StringID
# LoanID_2  02/01/2019     2200         45          365       3161       4096
# LoanID_4         NaN     2200         45          365       3141       4166
#
#           AmtPaid360 LoanStatus
# StringID
# LoanID_2       16041     Active
# LoanID_4       16321     Active

# %%
data.iloc[:,[3, 1]].head()
# Out:
#              Location    Product
# StringID
# LoanID_1   Location 3  Product B
# LoanID_2   Location 6  Product D
# LoanID_3   Location 8  Product B
# LoanID_4  Location 26  Product A
# LoanID_5  Location 34  Product B

# %%
data.loc['LoanID_1', 'Location']
# Out:
# 'Location 3'

# %% [markdown]
# ### loc
# - Sub-select information from the DataFrame by referring to its LABELS

# %%
data.sample(5)
# Out:
#              LoanID    Product CustomerGender     Location     Region  \
# StringID
# LoanID_727      727  Product B           Male  Location 86   Region 6
# LoanID_1004    1004  Product B           Male  Location 62   Region 2
# LoanID_572      572  Product A           Male   Location 5   Region 1
# LoanID_711      711  Product D         Female  Location 63  Region 10
# LoanID_185      185  Product B         Female  Location 37   Region 2
#
#              TotalPrice   StartDate  Deposit  DailyRate  TotalDaysYr  \
# StringID
# LoanID_727      17300.0  03/11/2018     2200         45          365
# LoanID_1004     16300.0  21/06/2016     1000         45          365
# LoanID_572      21950.0  11/06/2019     5000         55          365
# LoanID_711      20950.0  26/10/2017     2200         55          365
# LoanID_185      17600.0  31/08/2018     2200         45          365
#
#              AmtPaid36  AmtPaid60  AmtPaid360        LoanStatus
# StringID
# ...

# %%
data.loc['LoanID_31']
# Out:
# LoanID                     31
# Product             Product B
# CustomerGender           Male
# Location          Location 78
# Region               Region 3
# TotalPrice            17600.0
# StartDate          24/02/2018
# Deposit                  2200
# DailyRate                  45
# TotalDaysYr               365
# AmtPaid36                3141
# AmtPaid60                4156
# AmtPaid360              17361
# LoanStatus             Active
# Name: LoanID_31, dtype: object

# %%
import numpy as np
File = pd.read_excel('Mileage.xlsx')

# %%
File
# Out:
#    Type of vehicle    Size  mileage
# 0              Car   small    14.98
# 1              Car   small    17.74
# 2              Car   small    56.00
# 3              Car   small      NaN
# 4              Car   small    17.98
# 5              Car   small    14.76
# 6              Car   small    15.18
# 7              Car   small    43.00
# 8              Car   small    15.37
# 9              Car  medium    14.00
# 10             Car  medium    10.50
# 11             Car  medium    11.96
# 12             Car  medium    13.53
# 13             Car  medium      NaN
# 14             Car  medium    12.46
# 15             Car  medium    13.38
# 16             Car   large    30.00
# 17             Car   large    10.79
# 18             Car   large     9.57
# 19             Car   large     9.81
# 20             Car   large     8.19
# 21             Car   large    10.32
# 22           Truck   Small    12.32
# 23           Truck   Small      NaN
# 24           Truck   Small    13.22
# ...

# %%
File.head()
# Out:
#   Type of vehicle   Size  mileage
# 0             Car  small    14.98
# 1             Car  small    17.74
# 2             Car  small    56.00
# 3             Car  small      NaN
# 4             Car  small    17.98

# %%
File.tail()
# Out:
#    Type of vehicle    Size  mileage
# 42           Truck   Large     9.32
# 43             Car   small    17.98
# 44           Truck  Medium    10.78
# 45           Truck   Small    14.66
# 46           Truck   Small    14.93

# %%
File.describe()
# Out:
#          mileage
# count  40.000000
# mean   15.286250
# std     9.982015
# min     5.290000
# 25%    10.702500
# 50%    12.390000
# 75%    14.942500
# max    56.000000

# %%
len(File)
# Out:
# 47

# %%
File.nunique()
# Out:
# Type of vehicle     2
# Size                6
# mileage            36
# dtype: int64

# %%
File.head()
# Out:
#   Type of vehicle   Size  mileage
# 0             Car  small    14.98
# 1             Car  small    17.74
# 2             Car  small    56.00
# 3             Car  small      NaN
# 4             Car  small    17.98

# %%
import numpy as np
File['mileage'].unique()
# Out:
# array([14.98, 17.74, 56.  ,   nan, 17.98, 14.76, 15.18, 43.  , 15.37,
#        14.  , 10.5 , 11.96, 13.53, 12.46, 13.38, 30.  , 10.79,  9.57,
#         9.81,  8.19, 10.32, 12.32, 13.22, 14.66, 14.93, 12.  , 11.54,
#        10.77, 40.  , 11.34, 11.94, 10.78,  8.74,  9.59,  7.14,  5.29,
#         9.32])

# %%
File.sample(5)
# Out:
#    Type of vehicle    Size  mileage
# 22           Truck   Small    12.32
# 44           Truck  Medium    10.78
# 15             Car  medium    13.38
# 37           Truck   Large      NaN
# 35           Truck   Large     8.74

# %%
File.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type of vehicle  47 non-null     object
#  1   Size             47 non-null     object
#  2   mileage          40 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.2+ KB

# %%
File.isnull()
# Out:
#     Type of vehicle   Size  mileage
# 0             False  False    False
# 1             False  False    False
# 2             False  False    False
# 3             False  False     True
# 4             False  False    False
# 5             False  False    False
# 6             False  False    False
# 7             False  False    False
# 8             False  False    False
# 9             False  False    False
# 10            False  False    False
# 11            False  False    False
# 12            False  False    False
# 13            False  False     True
# 14            False  False    False
# 15            False  False    False
# 16            False  False    False
# 17            False  False    False
# 18            False  False    False
# 19            False  False    False
# 20            False  False    False
# 21            False  False    False
# 22            False  False    False
# 23            False  False     True
# 24            False  False    False
# ...

# %%
File.isnull().sum()
# Out:
# Type of vehicle    0
# Size               0
# mileage            7
# dtype: int64

# %%
File.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39     True
# 40     True
# 41    False
# 42    False
# 43     True
# 44     True
# 45     True
# 46     True
# dtype: bool

# %%
File.duplicated().sum()
# Out:
# 6

# %%
File.rename(columns={'Type of vehicle': 'Vehicle types'})
# Out:
#    Vehicle types    Size  mileage
# 0            Car   small    14.98
# 1            Car   small    17.74
# 2            Car   small    56.00
# 3            Car   small      NaN
# 4            Car   small    17.98
# 5            Car   small    14.76
# 6            Car   small    15.18
# 7            Car   small    43.00
# 8            Car   small    15.37
# 9            Car  medium    14.00
# 10           Car  medium    10.50
# 11           Car  medium    11.96
# 12           Car  medium    13.53
# 13           Car  medium      NaN
# 14           Car  medium    12.46
# 15           Car  medium    13.38
# 16           Car   large    30.00
# 17           Car   large    10.79
# 18           Car   large     9.57
# 19           Car   large     9.81
# 20           Car   large     8.19
# 21           Car   large    10.32
# 22         Truck   Small    12.32
# 23         Truck   Small      NaN
# 24         Truck   Small    13.22
# 25         Truck   Small    14.66
# ...

# %%
#for pemanent change- 
File.rename(columns={'Type of vehicle': 'Vehicle types'}, inplace = True)

# %% [markdown]
# ### Math methods

# %%
#sum
File.head()
# Out:
#   Vehicle types   Size  mileage
# 0           Car  small    14.98
# 1           Car  small    17.74
# 2           Car  small    56.00
# 3           Car  small      NaN
# 4           Car  small    17.98

# %% [markdown]
# - Row sum (axis = 1)
# - Column sum (axis = 0)

# %%
#single col
File['Size']
# Out:
# 0      small
# 1      small
# 2      small
# 3      small
# 4      small
# 5      small
# 6      small
# 7      small
# 8      small
# 9     medium
# 10    medium
# 11    medium
# 12    medium
# 13    medium
# 14    medium
# 15    medium
# 16     large
# 17     large
# 18     large
# 19     large
# 20     large
# 21     large
# 22     Small
# 23     Small
# 24     Small
# 25     Small
# 26     Small
# 27    Medium
# 28    Medium
# 29    Medium
# 30    Medium
# 31    Medium
# 32    Medium
# 33    Medium
# 34    Medium
# 35     Large
# 36     Large
# 37     Large
# 38     Large
# 39     Large
# 40     Large
# 41     Large
# 42     Large
# 43     small
# 44    Medium
# 45     Small
# 46     Small
# Name: Size, dtype: object

# %%
# fteching multiple col
File[['Size', 'mileage']]
# Out:
#       Size  mileage
# 0    small    14.98
# 1    small    17.74
# 2    small    56.00
# 3    small      NaN
# 4    small    17.98
# 5    small    14.76
# 6    small    15.18
# 7    small    43.00
# 8    small    15.37
# 9   medium    14.00
# 10  medium    10.50
# 11  medium    11.96
# 12  medium    13.53
# 13  medium      NaN
# 14  medium    12.46
# 15  medium    13.38
# 16   large    30.00
# 17   large    10.79
# 18   large     9.57
# 19   large     9.81
# 20   large     8.19
# 21   large    10.32
# 22   Small    12.32
# 23   Small      NaN
# 24   Small    13.22
# 25   Small    14.66
# 26   Small    14.93
# 27  Medium    12.00
# 28  Medium    11.54
# 29  Medium    10.77
# 30  Medium    40.00
# 31  Medium    11.34
# 32  Medium    11.94
# 33  Medium      NaN
# 34  Medium    10.78
# 35   Large     8.74
# 36   Large     9.59
# 37   Large      NaN
# 38   Large     7.14
# 39   Large      NaN
# 40   Large      NaN
# 41   Large     5.29
# 42   Large     9.32
# 43   small    17.98
# ...

# %%
#inplace is used to make permanent

# %%
# fetching single row
File.iloc[0]
# Out:
# Vehicle types      Car
# Size             small
# mileage          14.98
# Name: 0, dtype: object

# %%
#multiple
File.iloc[0:10]
# Out:
#   Vehicle types    Size  mileage
# 0           Car   small    14.98
# 1           Car   small    17.74
# 2           Car   small    56.00
# 3           Car   small      NaN
# 4           Car   small    17.98
# 5           Car   small    14.76
# 6           Car   small    15.18
# 7           Car   small    43.00
# 8           Car   small    15.37
# 9           Car  medium    14.00

# %%
#fancy indexing
File.iloc[[1,4,8]]
# Out:
#   Vehicle types   Size  mileage
# 1           Car  small    17.74
# 4           Car  small    17.98
# 8           Car  small    15.37

# %%
File = pd.DataFrame(File)
File.set_index('Vehicle types').head()
# Out:
#                 Size  mileage
# Vehicle types
# Car            small    14.98
# Car            small    17.74
# Car            small    56.00
# Car            small      NaN
# Car            small    17.98

# %% [markdown]
# loc - fetch with the label

# %%
#loc

# %% [markdown]
# ### Selecting both rows and cols

# %%
File.iloc[0:2,0:2]
# Out:
#   Vehicle types   Size
# 0           Car  small
# 1           Car  small

# %% [markdown]
# Create a Series object named emp_birth_date. This object should contain the birth dates of four specific employees, each identified by their employee number, as outlined below:

# %%
import numpy as np
import pandas as pd
emp_birth_date = {'No_0001' :'1963-08-02' , 'No_0002': '1964-06-13', 'No_0003': '1989-12-04', 'No_0004': '1996-04-08'}

# %%
emp_birth_date
# Out:
# {'No_0001': '1963-08-02',
#  'No_0002': '1964-06-13',
#  'No_0003': '1989-12-04',
#  'No_0004': '1996-04-08'}

# %%
Dates = list(emp_birth_date)
Dates
# Out:
# ['No_0001', 'No_0002', 'No_0003', 'No_0004']

# %%
df2 = pd.DataFrame(Dates)
df2
# Out:
#          0
# 0  No_0001
# 1  No_0002
# 2  No_0003
# 3  No_0004

# %% [markdown]
# ### Sorting
# - .sort_values() arranges the values of the object it's been applied to
# - The index values comply with the object's data that will lead the way

# %% [markdown]
# ## Example

# %%
import pandas as pd
ipl = pd.read_csv("ipl-matches.csv")

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [markdown]
# ### Question
# find all the final winners

# %%
ipl['MatchNumber'] == 'Final'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
m = ipl['MatchNumber'] == 'Final'

# %%
m
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 945    False
# 946    False
# 947    False
# 948    False
# 949    False
# Name: MatchNumber, Length: 950, dtype: bool

# %%
ipl[m]
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_df= ipl[m]

# %%
new_df
# Out:
#           ID          City        Date   Season MatchNumber  \
# 0    1312200     Ahmedabad  2022-05-29     2022       Final
# 74   1254117         Dubai  2021-10-15     2021       Final
# 134  1237181           NaN  2020-11-10  2020/21       Final
# 194  1181768     Hyderabad  2019-05-12     2019       Final
# 254  1136620        Mumbai  2018-05-27     2018       Final
# 314  1082650     Hyderabad  2017-05-21     2017       Final
# 373   981019     Bangalore  2016-05-29     2016       Final
# 433   829823       Kolkata  2015-05-24     2015       Final
# 492   734049     Bangalore  2014-06-01     2014       Final
# 552   598073       Kolkata  2013-05-26     2013       Final
# 628   548381       Chennai  2012-05-27     2012       Final
# 702   501271       Chennai  2011-05-28     2011       Final
# 775   419165        Mumbai  2010-04-25  2009/10       Final
# 835   392239  Johannesburg  2009-05-24     2009       Final
# 892   336040        Mumbai  2008-06-01  2007/08       Final
#
# ...

# %%
new_df[['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# - We can obtain the same result from a single line code

# %%
ipl[ipl['MatchNumber'] == 'Final'][['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %% [markdown]
# ### Question
# How many superover finishes have occured

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
mask = ipl['SuperOver'] == 'Y'
New_df = ipl[mask]
x = New_df[['SuperOver']]
x
# Out:
#     SuperOver
# 114         Y
# 158         Y
# 159         Y
# 184         Y
# 192         Y
# 203         Y
# 244         Y
# 339         Y
# 474         Y
# 533         Y
# 608         Y
# 621         Y
# 819         Y
# 883         Y

# %%
x.shape
# Out:
# (14, 1)

# %%
x.shape[0]
# Out:
# 14

# %% [markdown]
# ### Question
# How many matches CSK has won in Kolkata?

# %%
ipl.head(5)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
j = ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')]

# %%
j
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
j.shape
# Out:
# (5, 20)

# %%
j.shape[0]
# Out:
# 5

# %% [markdown]
# ### Question
# Toss winner is match winner in percentage

# %%
(ipl[ipl["TossWinner"] == ipl["WinningTeam"]].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
ipl["Team1Players"].str.split(' | ')
# Out:
# 0      [['YBK, Jaiswal',, 'JC, Buttler',, 'SV, Samson...
# 1      [['V, Kohli',, 'F, du, Plessis',, 'RM, Patidar...
# 2      [['V, Kohli',, 'F, du, Plessis',, 'RM, Patidar...
# 3      [['YBK, Jaiswal',, 'JC, Buttler',, 'SV, Samson...
# 4      [['PK, Garg',, 'Abhishek, Sharma',, 'RA, Tripa...
#                              ...
# 945    [['WP, Saha',, 'BB, McCullum',, 'RT, Ponting',...
# 946    [['L, Ronchi',, 'ST, Jayasuriya',, 'DJ, Thorne...
# 947    [['G, Gambhir',, 'V, Sehwag',, 'S, Dhawan',, '...
# 948    [['K, Goel',, 'JR, Hopes',, 'KC, Sangakkara',,...
# 949    [['R, Dravid',, 'W, Jaffer',, 'V, Kohli',, 'JH...
# Name: Team1Players, Length: 950, dtype: object

# %%
ipl["Team1Players"]
# Out:
# 0      ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#                              ...
# 945    ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
# Name: Team1Players, Length: 950, dtype: object

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ### Ploting Function

# %%
import matplotlib.pyplot as plt

# %%
ipl['WinningTeam'].value_counts()
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
ipl['WinningTeam'].head().value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='WinningTeam'>

# %%
ipl['WinningTeam'].head().value_counts().plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ipl['WinningTeam'].head().value_counts().plot(kind = 'barh')
# Out:
# <Axes: ylabel='WinningTeam'>

# %%
ipl['WinningTeam'].head().value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
ipl['WinningTeam'].head().value_counts().plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Series Operators

# %%
# if the series have same index then we can perform mathetical operations

# %%
myseries = ipl['WinningTeam'].value_counts()
myseries
# Out:
# WinningTeam
# Mumbai Indians                 131
# Chennai Super Kings            121
# Kolkata Knight Riders          114
# Royal Challengers Bangalore    109
# Rajasthan Royals                96
# Kings XI Punjab                 88
# Sunrisers Hyderabad             75
# Delhi Daredevils                67
# Delhi Capitals                  36
# Deccan Chargers                 29
# Gujarat Lions                   13
# Punjab Kings                    13
# Pune Warriors                   12
# Gujarat Titans                  12
# Rising Pune Supergiant          10
# Lucknow Super Giants             9
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
type(myseries)
# Out:
# pandas.core.series.Series

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl['Team1'].value_counts() + ipl['Team2'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
#sort
#drop_duplicates

# %% [markdown]
# Random

# %%
df = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
df
# Out:
#             0         1         2         3         4
# 0    0.973758  0.776589  0.421535  0.646558  0.599542
# 1    0.867356  0.574424  0.397000  0.471078  0.392146
# 2    0.803184  0.453463  0.632561  0.874132  0.122251
# 3    0.824896  0.057247  0.315794  0.149768  0.430181
# 4    0.810489  0.040037  0.288071  0.722267  0.183613
# ..        ...       ...       ...       ...       ...
# 329  0.835072  0.358842  0.732290  0.466309  0.236538
# 330  0.561178  0.902867  0.450632  0.319769  0.990356
# 331  0.131900  0.665345  0.496005  0.323979  0.421971
# 332  0.242301  0.180313  0.402218  0.072432  0.523428
# 333  0.494679  0.955306  0.113827  0.249193  0.282541
#
# [334 rows x 5 columns]

# %%
new_df = df.sort_index(axis = 0, ascending = False)

# %%
new_df
# Out:
#             0         1         2         3         4
# 333  0.494679  0.955306  0.113827  0.249193  0.282541
# 332  0.242301  0.180313  0.402218  0.072432  0.523428
# 331  0.131900  0.665345  0.496005  0.323979  0.421971
# 330  0.561178  0.902867  0.450632  0.319769  0.990356
# 329  0.835072  0.358842  0.732290  0.466309  0.236538
# ..        ...       ...       ...       ...       ...
# 4    0.810489  0.040037  0.288071  0.722267  0.183613
# 3    0.824896  0.057247  0.315794  0.149768  0.430181
# 2    0.803184  0.453463  0.632561  0.874132  0.122251
# 1    0.867356  0.574424  0.397000  0.471078  0.392146
# 0    0.973758  0.776589  0.421535  0.646558  0.599542
#
# [334 rows x 5 columns]

# %%
new_df = df.sort_index(axis = 1, ascending = False)

# %%
new_df
# Out:
#             4         3         2         1         0
# 0    0.599542  0.646558  0.421535  0.776589  0.973758
# 1    0.392146  0.471078  0.397000  0.574424  0.867356
# 2    0.122251  0.874132  0.632561  0.453463  0.803184
# 3    0.430181  0.149768  0.315794  0.057247  0.824896
# 4    0.183613  0.722267  0.288071  0.040037  0.810489
# ..        ...       ...       ...       ...       ...
# 329  0.236538  0.466309  0.732290  0.358842  0.835072
# 330  0.990356  0.319769  0.450632  0.902867  0.561178
# 331  0.421971  0.323979  0.496005  0.665345  0.131900
# 332  0.523428  0.072432  0.402218  0.180313  0.242301
# 333  0.282541  0.249193  0.113827  0.955306  0.494679
#
# [334 rows x 5 columns]

# %%
new_df.columns = list("ABCDE")

# %%
new_df
# Out:
#             A         B         C         D         E
# 0    0.599542  0.646558  0.421535  0.776589  0.973758
# 1    0.392146  0.471078  0.397000  0.574424  0.867356
# 2    0.122251  0.874132  0.632561  0.453463  0.803184
# 3    0.430181  0.149768  0.315794  0.057247  0.824896
# 4    0.183613  0.722267  0.288071  0.040037  0.810489
# ..        ...       ...       ...       ...       ...
# 329  0.236538  0.466309  0.732290  0.358842  0.835072
# 330  0.990356  0.319769  0.450632  0.902867  0.561178
# 331  0.421971  0.323979  0.496005  0.665345  0.131900
# 332  0.523428  0.072432  0.402218  0.180313  0.242301
# 333  0.282541  0.249193  0.113827  0.955306  0.494679
#
# [334 rows x 5 columns]

# %%
new_df.loc[0 , 'A']
# Out:
# 0.5995419877272303

# %%
new_df.loc[0 , 'A'] = 234

# %%
new_df
# Out:
#               A         B         C         D         E
# 0    234.000000  0.646558  0.421535  0.776589  0.973758
# 1      0.392146  0.471078  0.397000  0.574424  0.867356
# 2      0.122251  0.874132  0.632561  0.453463  0.803184
# 3      0.430181  0.149768  0.315794  0.057247  0.824896
# 4      0.183613  0.722267  0.288071  0.040037  0.810489
# ..          ...       ...       ...       ...       ...
# 329    0.236538  0.466309  0.732290  0.358842  0.835072
# 330    0.990356  0.319769  0.450632  0.902867  0.561178
# 331    0.421971  0.323979  0.496005  0.665345  0.131900
# 332    0.523428  0.072432  0.402218  0.180313  0.242301
# 333    0.282541  0.249193  0.113827  0.955306  0.494679
#
# [334 rows x 5 columns]

# %%
#drop 
new_df.drop('E', axis = 1, inplace = True) # axis 1 then it will remove from coloumn otherwise row

# %%
new_df
# Out:
#               A         B         C         D
# 0    234.000000  0.646558  0.421535  0.776589
# 1      0.392146  0.471078  0.397000  0.574424
# 2      0.122251  0.874132  0.632561  0.453463
# 3      0.430181  0.149768  0.315794  0.057247
# 4      0.183613  0.722267  0.288071  0.040037
# ..          ...       ...       ...       ...
# 329    0.236538  0.466309  0.732290  0.358842
# 330    0.990356  0.319769  0.450632  0.902867
# 331    0.421971  0.323979  0.496005  0.665345
# 332    0.523428  0.072432  0.402218  0.180313
# 333    0.282541  0.249193  0.113827  0.955306
#
# [334 rows x 4 columns]

# %%
new_df.loc[(new_df['A']<0.3) & (new_df['C']>0.1)]
# Out:
#             A         B         C         D
# 2    0.122251  0.874132  0.632561  0.453463
# 4    0.183613  0.722267  0.288071  0.040037
# 5    0.146288  0.030687  0.675616  0.470762
# 7    0.113347  0.476645  0.913469  0.808922
# 16   0.055387  0.978722  0.609702  0.828019
# ..        ...       ...       ...       ...
# 323  0.160229  0.738148  0.167543  0.284084
# 327  0.198991  0.239763  0.586714  0.147222
# 328  0.089799  0.520928  0.825912  0.224292
# 329  0.236538  0.466309  0.732290  0.358842
# 333  0.282541  0.249193  0.113827  0.955306
#
# [102 rows x 4 columns]

# %%
new_df.iloc[0,1]
# Out:
# 0.6465577943360566

# %%
new_df.iloc[:, 1]
# Out:
# 0      0.646558
# 1      0.471078
# 2      0.874132
# 3      0.149768
# 4      0.722267
#          ...
# 329    0.466309
# 330    0.319769
# 331    0.323979
# 332    0.072432
# 333    0.249193
# Name: B, Length: 334, dtype: float64

# %%
new_df.iloc[[0,5],[1,2]]
# Out:
#           B         C
# 0  0.646558  0.421535
# 5  0.030687  0.675616

# %%
df2 = {"Name":['Mohit', 'Ram', 'Albert','Albert', 'Mohit'],
       "Rank": [2,1,3,3,2]}

# %%
df2
# Out:
# {'Name': ['Mohit', 'Ram', 'Albert', 'Albert', 'Mohit'],
#  'Rank': [2, 1, 3, 3, 2]}

# %%
type(df2)
# Out:
# dict

# %%
df2_new = pd.DataFrame(df2)

# %%
df2_new
# Out:
#      Name  Rank
# 0   Mohit     2
# 1     Ram     1
# 2  Albert     3
# 3  Albert     3
# 4   Mohit     2

# %%
index=df2_new['Name']
index
df2_new
# Out:
#      Name  Rank
# 0   Mohit     2
# 1     Ram     1
# 2  Albert     3
# 3  Albert     3
# 4   Mohit     2

# %%
#Removing duplicates
#drop_duplicates
df2_new.drop_duplicates(subset=['Name'], keep = 'first')f
# Out:
#   Cell In[166], line 3
#     df2_new.drop_duplicates(subset=['Name'], keep = 'first')f
#                                                             ^
# SyntaxError: invalid syntax

# %%
df2_new.drop_duplicates(subset=['Name'], keep = 'last')
# Out:
#      Name  Rank
# 1     Ram     1
# 3  Albert     3
# 4   Mohit     2

# %%
df2_new.drop_duplicates(subset=['Rank'], keep = 'last')
# Out:
#      Name  Rank
# 1     Ram     1
# 3  Albert     3
# 4   Mohit     2

# %%
import pandas as pd
import numpy as np

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
Venues = ipl.groupby('Venue')

# %%
Venues

# %%
len(ipl)
# Out:
# 950

# %%
len('Venues')
# Out:
# 6

# %%
Venues.size().sort_values(ascending = False)
# Out:
# Venue
# Eden Gardens                                            77
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Feroz Shah Kotla                                        60
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Sawai Mansingh Stadium                                  47
# Dubai International Cricket Stadium                     46
# Punjab Cricket Association Stadium, Mohali              35
# Wankhede Stadium, Mumbai                                31
# Sheikh Zayed Stadium                                    29
# Sharjah Cricket Stadium                                 28
# Maharashtra Cricket Association Stadium                 22
# Dr DY Patil Sports Academy, Mumbai                      20
# Dr DY Patil Sports Academy                              17
# Brabourne Stadium, Mumbai                               17
# ...

# %%
Venues.first()
# Out:
#                                                          ID            City  \
# Venue
# Arun Jaitley Stadium                                1178428           Delhi
# Arun Jaitley Stadium, Delhi                         1254085           Delhi
# Barabati Stadium                                     734009         Cuttack
# Brabourne Stadium                                    829811          Mumbai
# Brabourne Stadium, Mumbai                           1304114          Mumbai
# Buffalo Park                                         392215     East London
# De Beers Diamond Oval                                392220       Kimberley
# Dr DY Patil Sports Academy                           501262          Mumbai
# Dr DY Patil Sports Academy, Mumbai                  1304112     Navi Mumbai
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...  1181767   Visakhapatnam
# Dubai International Cricket Stadium                 1254117           Dubai
# ...

# %%
Venues.last()
# Out:
#                                                          ID            City  \
# Venue
# Arun Jaitley Stadium                                1136582           Delhi
# Arun Jaitley Stadium, Delhi                         1254080           Delhi
# Barabati Stadium                                     419117         Cuttack
# Brabourne Stadium                                    419107          Mumbai
# Brabourne Stadium, Mumbai                            419125          Mumbai
# Buffalo Park                                         392203     East London
# De Beers Diamond Oval                                392217       Kimberley
# Dr DY Patil Sports Academy                           335994          Mumbai
# Dr DY Patil Sports Academy, Mumbai                  1304049          Mumbai
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...   548311   Visakhapatnam
# Dubai International Cricket Stadium                  729287           Dubai
# ...

# %%
import pandas as pd

# %%
Mileage_avg = pd.read_excel("Mileage.xlsx")
Mileage_avg.head()
# Out:
#   Type of vehicle   Size  mileage
# 0             Car  small    14.98
# 1             Car  small    17.74
# 2             Car  small    56.00
# 3             Car  small      NaN
# 4             Car  small    17.98

# %%
Mileage_avg.dropna(inplace = True)

# %%
group_by_mileage = Mileage_avg.groupby(['Type of vehicle', 'Size']).mean()

# %%
group_by_mileage
# Out:
#                           mileage
# Type of vehicle Size
# Car             large   13.113333
#                 medium  12.638333
#                 small   23.665556
# Truck           Large    8.016000
#                 Medium  14.893750
#                 Small   14.120000

# %%
Mileage_avg.head()
# Out:
#   Type of vehicle   Size  mileage
# 0             Car  small    14.98
# 1             Car  small    17.74
# 2             Car  small    56.00
# 4             Car  small    17.98
# 5             Car  small    14.76

# %%
m = Mileage_avg[['Size','mileage']].groupby('Size')

# %%
m.mean()
# Out:
#           mileage
# Size
# Large    8.016000
# Medium  14.893750
# Small   14.120000
# large   13.113333
# medium  12.638333
# small   23.665556

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Life Expectancy Data.csv")

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info
# Out:
# <bound method DataFrame.info of           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
#finding missing value
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64
