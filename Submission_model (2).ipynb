# %% [markdown]
# ### Problem Statement
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and predict the sales of each product at a particular outlet.
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.
#
# Please note that the data may have missing values as some stores might not report all the data due to technical glitches. Hence, it will be required to treat them accordingly.

# %% [markdown]
# ### OBJECTIVE
# ### The aim is to build a predictive model and predict the sales of each product at a particular outlet.

# %% [markdown]
# #### Data Preprocessing- Before Building Machine learning model
#
# ### Steps of preprocessing of data
# 1. Import necessary library
# 2. Read Dataset
# 3. Sanity check of data
# 4. Exploratory Data Analysis(EDA)
# 5. Missing Value Treatments
# 6. Outliers treatments
# 7. Duplicated & garbage value treatments
# 8. Normalization
# 9. Encoding of Data

# %% [markdown]
# ## NOTE -
# ### We have performed all the steps in the other file named "Prediction", it's link is also there you can view it for seeing all the steps

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleandf.csv")
test = pd.read_csv("test_AbJTz2l.csv")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30           LowFat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50           LowFat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93           LowFat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
# List of unique outlet identifiers and sizes
unique_identifiers = test['Item_Identifier'].unique()

# Loop through each combination of identifier and size
for identifier in unique_identifiers:
        mask = (test['Item_Identifier'] == identifier)
        filtered_test = test[mask]
        q = filtered_test["Item_Weight"].min()
        r = filtered_test["Item_Weight"].max()
        if q == r:
            test.Item_Weight[test.Item_Weight.isnull()] = q
            print(identifier)
            print(q)
            print(r)
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_25340\60776725.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.Item_Weight[test.Item_Weight.isnull()] = q
# C:\Users\priya\AppData\Local\Temp\ipykernel_25340\60776725.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test.Item_Weight[test.Item_Weight.isnull()] = q
# C:\Users\priya\AppData\Local\Temp\ipykernel_25340\60776725.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                5681 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
nan_values = test[test["Outlet_Size"].isna()]
print(nan_values)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 8              FDN33        6.305          Regular         0.123365
# 9              FDA36        5.985          Low Fat         0.005698
# ...              ...          ...              ...              ...
# 5668           FDC44       15.600          Low Fat         0.288892
# 5670           FDO03       10.395          Regular         0.037092
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1                     Dairy   87.3198            OUT017
# ...

# %%
test["Outlet_Size"] = test["Outlet_Size"].fillna("Small")
print(test)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38       20.750          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
test.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
## Cleaning test data

# %%
test["Item_Fat_Content"].nunique()
# Out:
# 5

# %%
test["Item_Fat_Content"] = test["Item_Fat_Content"].replace("reg","Regular")

# %%
test["Item_Fat_Content"] = test["Item_Fat_Content"].replace("LF","Low Fat")

# %%
test["Item_Fat_Content"] = test["Item_Fat_Content"].replace("LF","Low Fat")

# %%
test["Item_Fat_Content"] = test["Item_Fat_Content"].replace("Low Fat" , "LowFat")

# %%
test["Item_Fat_Content"] = test["Item_Fat_Content"].replace("low fat" , "LowFat")

# %%
test["Item_Fat_Content"].nunique()
# Out:
# 2

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750           LowFat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600           LowFat         0.099575       Others
# 3           FDQ58        7.315           LowFat         0.015388  Snack Foods
# 4           FDY38       20.750          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007       Small
# 2  241.7538            OUT010                       1998       Small
# 3  155.0340            OUT017                       2007       Small
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30           LowFat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50           LowFat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93           LowFat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
import math
df["Sales_log"] = df.Item_Outlet_Sales.apply(lambda x: math.log(x))

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30           LowFat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50           LowFat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93           LowFat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ### Random Forest

# %%
train_X = df[["Item_Fat_Content", "Item_Visibility", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type", "Item_MRP"]]
y_train = df["Sales_log"]

test_X = test[["Item_Fat_Content", "Item_Visibility", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type", "Item_MRP"]]


# Identify categorical columns
categorical_cols = train_X.select_dtypes(include=["object"]).columns

# Apply one-hot encoding to categorical columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), categorical_cols)], remainder='passthrough')

# Fit and transform the training data
train_X_encoded = ct.fit_transform(train_X)

# Transform the testing data
test_X_encoded = ct.transform(test_X)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
# Fit the model to the training data
rf_model.fit(train_X_encoded, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_test = rf_model.predict(test_X_encoded)
y_pred_test
# Out:
# array([7.28968503, 7.14628516, 6.10187837, ..., 7.58452426, 8.38362872,
#        7.33205553])

# %%
import numpy as np

y_pred_test = rf_model.predict(test_X_encoded)

# Take the antilog (base e) of the predictions
y_pred_test_antilog = np.exp(y_pred_test)

print(y_pred_test_antilog)
# Out:
# [1465.10916632 1269.38163338  446.69604142 ... 1967.51039255 4374.85526631
#  1528.52046471]

# %%
if not isinstance(y_pred_test_antilog, pd.DataFrame):
    y_pred_test_antilog_df = pd.DataFrame({'y_pred_test_antilog': y_pred_test_antilog})
else:
    y_pred_test_antilog_df = y_pred_test_antilog  # Already a DataFrame

# Merge DataFrames (ensure they have the same number of rows)
merged_df_rf = pd.concat([Submission_File, y_pred_test_antilog_df], axis=1)

print(merged_df_rf)
# Out:
#      Item_Identifier Outlet_Identifier  y_pred_test_antilog
# 0              FDW58            OUT049          1465.109166
# 1              FDW14            OUT017          1269.381633
# 2              NCN55            OUT010           446.696041
# 3              FDQ58            OUT017          1613.995788
# 4              FDY38            OUT027          5162.514912
# ...              ...               ...                  ...
# 5676           FDB58            OUT046          2531.368110
# 5677           FDD47            OUT018          2183.758580
# 5678           NCO17            OUT045          1967.510393
# 5679           FDJ26            OUT017          4374.855266
# 5680           FDU37            OUT045          1528.520465
#
# [5681 rows x 3 columns]

# %%
merged_df_rf
# Out:
#      Item_Identifier Outlet_Identifier  y_pred_test_antilog
# 0              FDW58            OUT049          1465.109166
# 1              FDW14            OUT017          1269.381633
# 2              NCN55            OUT010           446.696041
# 3              FDQ58            OUT017          1613.995788
# 4              FDY38            OUT027          5162.514912
# ...              ...               ...                  ...
# 5676           FDB58            OUT046          2531.368110
# 5677           FDD47            OUT018          2183.758580
# 5678           NCO17            OUT045          1967.510393
# 5679           FDJ26            OUT017          4374.855266
# 5680           FDU37            OUT045          1528.520465
#
# [5681 rows x 3 columns]

# %%
final_submission = "rf_merged_data.csv"

merged_df_rf.to_csv(final_submission, index=False)

print("Merged DataFrame saved as", final_submission)
# Out:
# Merged DataFrame saved as rf_merged_data.csv

# %%
#import pandas as pd
#from sklearn.linear_model import LinearRegression
#from sklearn.preprocessing import OneHotEncoder #ColumnTransformer

#def train_and_predict(train_data_path, test_data_path):
 # """
 # Trains a linear regression model and returns predictions on test data.

 # Args:
  #    train_data_path (str): Path to the training data CSV file.
   #   test_data_path (str): Path to the testing data CSV file.

 # Returns:
  #    pandas.DataFrame: Combined DataFrame containing original data and predicted values.
 # """

  # Read data
 # df_train = pd.read_csv(train_data_path)
  #df_test = pd.read_csv(test_data_path)

# %%
# Separate features and target
train_X = df[["Item_Fat_Content", "Item_Visibility", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type", "Item_MRP"]]
y_train = df["Sales_log"]
test_X = test[["Item_Fat_Content", "Item_Visibility", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type", "Item_MRP"]]

# Identify categorical columns
categorical_cols = train_X.select_dtypes(include=["object"]).columns

# Apply one-hot encoding
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), categorical_cols)], remainder='passthrough')
train_X_encoded = ct.fit_transform(train_X)
test_X_encoded = ct.transform(test_X)

  # Train linear regression model
lr_model = LinearRegression()
lr_model.fit(train_X_encoded, y_train)

  # Predict on test data
y_pred_test = lr_model.predict(test_X_encoded)

  # Antilog for actual sales values (if needed)
y_pred_test_antilog = np.exp(y_pred_test)  # Uncomment for antilog transformation

#Combine original data (test set) with predictions
combined_data = pd.concat([test_X, pd.DataFrame({"Predicted Value": y_pred_test_antilog if 'y_pred_test_antilog' in locals() else y_pred_test})], axis=1)

# Example usage (replace with your actual file paths)
#data = train_and_predict("path/to/train_data.csv", "path/to/test_data.csv")
#print(data.head())  # Print the first few rows of the combined data

# %%
combined_data
# Out:
#      Item_Fat_Content  Item_Visibility           Item_Type Outlet_Size  \
# 0              LowFat         0.007565         Snack Foods      Medium
# 1             Regular         0.038428               Dairy       Small
# 2              LowFat         0.099575              Others       Small
# 3              LowFat         0.015388         Snack Foods       Small
# 4             Regular         0.118599               Dairy      Medium
# ...               ...              ...                 ...         ...
# 5676          Regular         0.013496         Snack Foods       Small
# 5677          Regular         0.142991       Starchy Foods      Medium
# 5678           LowFat         0.073529  Health and Hygiene       Small
# 5679          Regular         0.000000              Canned       Small
# 5680          Regular         0.104720              Canned       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_MRP  Predicted Value
# ...

# %% [markdown]
# ### Linear Regression

# %%
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor


train_X = df[["Item_Fat_Content", "Item_Visibility", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type", "Item_MRP"]]
y_train = df["Sales_log"]


test_X = test[["Item_Fat_Content", "Item_Visibility", "Item_Type", "Outlet_Size", "Outlet_Location_Type", "Outlet_Type", "Item_MRP"]]

 #Identify categorical columns
categorical_cols = train_X.select_dtypes(include=["object"]).columns

# Apply one-hot encoding to categorical columns
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), categorical_cols)], remainder='passthrough')

# Fit and transform the training data
train_X_encoded = ct.fit_transform(train_X)

# Transform the testing data
test_X_encoded = ct.transform(test_X)

# Instantiate the Linear Regression model
lr_model = LinearRegression()

# Fit the model using the encoded data
lr_model.fit(train_X_encoded, y_train)
# Out:
# LinearRegression()

# %%
lr_model.score(train_X_encoded,y_train)
# Out:
# 0.7208283837772949

# %%
y_pred_test = lr_model.predict(test_X_encoded)
y_pred_test
# Out:
# array([7.27129453, 7.02280058, 6.38411797, ..., 7.34751585, 8.17834193,
#        7.05056114])

# %%
import numpy as np

# ... (your existing code for training the model)

y_pred_test = lr_model.predict(test_X_encoded)

# Take the antilog (base e) of the predictions
y_pred_test_antilog = np.exp(y_pred_test)

print(y_pred_test_antilog)
# Out:
# [1438.41131499 1121.92426596  592.36202259 ... 1552.3355033  3562.9421695
#  1153.50584056]

# %%
# Combine original data with predictions
#combined_data = pd.concat([test_X_encoded, pd.DataFrame({"Predicted Value": y_pred_test_antilog})], axis=1)

# Return the DataFrame for Power BI
#return combined_data

# %%
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750           LowFat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600           LowFat         0.099575       Others
# 3           FDQ58        7.315           LowFat         0.015388  Snack Foods
# 4           FDY38       20.750          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007       Small
# 2  241.7538            OUT010                       1998       Small
# 3  155.0340            OUT017                       2007       Small
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
df_dropped_label = test.drop('Item_Weight', axis=1)  # axis=1 specifies dropping columns

# %%
df_dropped_label
# Out:
#      Item_Identifier Item_Fat_Content  Item_Visibility           Item_Type  \
# 0              FDW58           LowFat         0.007565         Snack Foods
# 1              FDW14          Regular         0.038428               Dairy
# 2              NCN55           LowFat         0.099575              Others
# 3              FDQ58           LowFat         0.015388         Snack Foods
# 4              FDY38          Regular         0.118599               Dairy
# ...              ...              ...              ...                 ...
# 5676           FDB58          Regular         0.013496         Snack Foods
# 5677           FDD47          Regular         0.142991       Starchy Foods
# 5678           NCO17           LowFat         0.073529  Health and Hygiene
# 5679           FDJ26          Regular         0.000000              Canned
# 5680           FDU37          Regular         0.104720              Canned
#
# ...

# %%
columns_to_keep = ['Item_Identifier', 'Outlet_Identifier']
Submission_File = test[columns_to_keep]

# %%
Submission_File
# Out:
#      Item_Identifier Outlet_Identifier
# 0              FDW58            OUT049
# 1              FDW14            OUT017
# 2              NCN55            OUT010
# 3              FDQ58            OUT017
# 4              FDY38            OUT027
# ...              ...               ...
# 5676           FDB58            OUT046
# 5677           FDD47            OUT018
# 5678           NCO17            OUT045
# 5679           FDJ26            OUT017
# 5680           FDU37            OUT045
#
# [5681 rows x 2 columns]

# %%
import pandas as pd

# Assuming 'y_pred_test_antilog' is a Series and 'Submission_File' is your DataFrame

# Create a DataFrame from the Series if necessary
if not isinstance(y_pred_test_antilog, pd.DataFrame):
    y_pred_test_antilog_df = pd.DataFrame({'y_pred_test_antilog': y_pred_test_antilog})
else:
    y_pred_test_antilog_df = y_pred_test_antilog  # Already a DataFrame

# Merge DataFrames (ensure they have the same number of rows)
merged_df = pd.concat([Submission_File, y_pred_test_antilog_df], axis=1)

print(merged_df)
# Out:
#      Item_Identifier Outlet_Identifier  y_pred_test_antilog
# 0              FDW58            OUT049          1438.411315
# 1              FDW14            OUT017          1121.924266
# 2              NCN55            OUT010           592.362023
# 3              FDQ58            OUT017          2081.997115
# 4              FDY38            OUT027          6370.705557
# ...              ...               ...                  ...
# 5676           FDB58            OUT046          1841.238703
# 5677           FDD47            OUT018          1863.547799
# 5678           NCO17            OUT045          1552.335503
# 5679           FDJ26            OUT017          3562.942170
# 5680           FDU37            OUT045          1153.505841
#
# [5681 rows x 3 columns]

# %%
merged_df
# Out:
#      Item_Identifier Outlet_Identifier  y_pred_test_antilog
# 0              FDW58            OUT049          1438.411315
# 1              FDW14            OUT017          1121.924266
# 2              NCN55            OUT010           592.362023
# 3              FDQ58            OUT017          2081.997115
# 4              FDY38            OUT027          6370.705557
# ...              ...               ...                  ...
# 5676           FDB58            OUT046          1841.238703
# 5677           FDD47            OUT018          1863.547799
# 5678           NCO17            OUT045          1552.335503
# 5679           FDJ26            OUT017          3562.942170
# 5680           FDU37            OUT045          1153.505841
#
# [5681 rows x 3 columns]
